# %%
# %matplotlib inline
import pylab
import pandas as pd
import glob
from collections import defaultdict
import sourmash
from sourmash.lca import lca_utils

# %%
sample_id='SRR606249'
#sample_id = 'p8808mo9'
#sample_id = 'p8808mo11'
outdir = 'outputs.podar.protein'

# %%
from IPython.display import Markdown as md
from IPython.display import display
md(f"# genome-grist gathergram for metagenome `{sample_id}` - PROTEIN")
# Out:
# # genome-grist gathergram for metagenome `SRR606249` - PROTEIN

# %% [markdown]
# ## load mapping summary CSVs and gather CSV

# %%
# load gather CSV
gather_df = pd.read_csv(f'{outdir}/genbank/{sample_id}.x.genbank.gather.csv')

# names!
names_df = pd.read_csv(f'{outdir}/genbank/{sample_id}.genomes.info.csv')

# connect gather_df to all_df and left_df using 'genome_id'
def fix_name(x):
    return "_".join(x.split('_')[:2]).split('.')[0]

gather_df['genome_id'] = gather_df['name'].apply(fix_name)
names_df['genome_id'] = names_df['acc'].apply(fix_name)

# %%
# CTB bug FIXME - should this ever happen??
# this ensures that only rows that share genome_id are in all the dataframes
in_gather = set(gather_df.genome_id)
names_df = names_df[names_df.genome_id.isin(in_gather)]

# reassign index now that we've maybe dropped rows
gather_df.index = range(len(gather_df))
names_df.index = range(len(names_df))

assert len(names_df) == len(gather_df)

# %%
# re-sort names_df to match gather_df order, using matching genome_id column
names_df.set_index("genome_id")
names_df.reindex(index=gather_df["genome_id"])
_ = names_df.reset_index()

# %%
# load and parse lineages
lineage_files = glob.glob('../genome-grist/genbank_lineages/*.csv')

lineages_df = pd.DataFrame()

for filename in lineage_files:
    print(f"reading {filename}")
    this_df = pd.read_csv(filename)
    this_df = this_df[this_df.accession.isin(in_gather)]
    lineages_df = lineages_df.append(this_df)
    
lineages_df
# Out:
# reading ../genome-grist/genbank_lineages/viral_genbank_lineage.csv
# reading ../genome-grist/genbank_lineages/protozoa_refseq_lineage.csv
# reading ../genome-grist/genbank_lineages/bacteria_genbank_lineage.csv
# reading ../genome-grist/genbank_lineages/protozoa_genbank_lineage.csv
# reading ../genome-grist/genbank_lineages/fungi_genbank_lineage.csv
# reading ../genome-grist/genbank_lineages/archaea_genbank_lineage.csv
# reading ../genome-grist/genbank_lineages/viral_refseq_lineage.csv
# reading ../genome-grist/genbank_lineages/bacteria_refseq_lineage.csv
# reading ../genome-grist/genbank_lineages/archaea_refseq_lineage.csv
# reading ../genome-grist/genbank_lineages/fungi_refseq_lineage.csv
#             accession    taxid superkingdom               phylum  \
# 151     GCA_000018565   316274     Bacteria          Chloroflexi
# 635     GCA_000008085   228908      Archaea        Nanoarchaeota
# 2187    GCA_002507545  1915565      Archaea        Euryarchaeota
# 2789    GCA_002201895  1937005      Archaea        Euryarchaeota
# 267     GCF_000008185   243275     Bacteria         Spirochaetes
# 24440   GCF_000175255   555217     Bacteria       Proteobacteria
# 64650   GCF_000025985   272559     Bacteria        Bacteroidetes
# 65011   GCF_000012825   435590     Bacteria        Bacteroidetes
# 65280   GCF_000010505   431947     Bacteria        Bacteroidetes
# 65354   GCF_000196135   273121     Bacteria       Proteobacteria
# 65376   GCF_000158275   457405     Bacteria         Fusobacteria
# 65659   GCF_003201195      916     Bacteria       Proteobacteria
# 65994   GCF_000016085   290318     Bacteria             Chlorobi
# 66002   GCF_000006985   194439     Bacteria             Chlorobi
# 66006   GCF_000018865   324602     Bacteria          Chloroflexi
# 79982   GCF_000008565   243230     Bacteria  Deinococcus-Thermus
# 94885   GCF_000392875  1169286     Bacteria           Firmicutes
# 104554  GCF_000015865   203119     Bacteria           Firmicutes
# 119755  GCF_000008545   243274     Bacteria          Thermotogae
# 136455  GCF_000022325   521460     Bacteria           Firmicutes
# 138326  GCF_000022565   240015     Bacteria        Acidobacteria
# 138848  GCF_000007985   243231     Bacteria       Proteobacteria
# 140989  GCF_000381045  1123391     Bacteria  Deinococcus-Thermus
# 141249  GCF_001598875  1236544     Bacteria       Proteobacteria
# 143932  GCF_004216565    47994     Bacteria       Proteobacteria
# 145707  GCF_900106935    60137     Bacteria       Proteobacteria
# 148743  GCF_000011965   246200     Bacteria       Proteobacteria
# 149954  GCF_000009705   103690     Bacteria        Cyanobacteria
# 153864  GCF_006716065   168697     Bacteria       Actinobacteria
# 153917  GCF_002902965   169430     Bacteria       Proteobacteria
# 154114  GCF_000010305   379066     Bacteria     Gemmatimonadetes
# 156222  GCF_000020225   349741     Bacteria      Verrucomicrobia
# 157457  GCF_000196115   243090     Bacteria       Planctomycetes
# 158365  GCF_000226255   298701     Bacteria       Proteobacteria
# 158569  GCF_000021565   123214     Bacteria            Aquificae
# 160488  GCF_000701905  1410668     Bacteria           Firmicutes
# 161269  GCF_000020325   436114     Bacteria            Aquificae
# 162643  GCF_000019085   340099     Bacteria           Firmicutes
# 162840  GCF_000021645   515635     Bacteria          Dictyoglomi
# 163143  GCF_000213785   547143     Bacteria            Aquificae
# 164950  GCF_003201595   744406     Bacteria       Proteobacteria
# 168375  GCF_001544555  1232866     Bacteria       Proteobacteria
# 44      GCF_000091665   243232      Archaea        Euryarchaeota
# 62      GCF_000970205   213585      Archaea        Euryarchaeota
# 143     GCF_000025685   309800      Archaea        Euryarchaeota
# 158     GCF_000007305   186497      Archaea        Euryarchaeota
# 252     GCF_000007225   178306      Archaea        Crenarchaeota
# 283     GCF_002945325    39152      Archaea        Euryarchaeota
# 429     GCF_000011205   273063      Archaea        Crenarchaeota
# 452     GCF_000017945   453591      Archaea        Crenarchaeota
# 546     GCF_000025665   439481      Archaea        Euryarchaeota
#
#                         class                   order  \
# 151              Chloroflexia       Herpetosiphonales
# 635                       NaN          Nanoarchaeales
# 2187             Archaeoglobi         Archaeoglobales
# 2789              Methanopyri          Methanopyrales
# 267              Spirochaetia          Spirochaetales
# 24440     Alphaproteobacteria        Sphingomonadales
# 64650             Bacteroidia           Bacteroidales
# 65011             Bacteroidia           Bacteroidales
# 65280             Bacteroidia           Bacteroidales
# 65354   Epsilonproteobacteria       Campylobacterales
# 65376           Fusobacteriia         Fusobacteriales
# 452               Ignicoccus                Ignicoccus hospitalis
# 546         Aciduliprofundum              Aciduliprofundum boonei
#
#                                                 strain
# 151                  Herpetosiphon aurantiacus DSM 785
# 635                       Nanoarchaeum equitans Kin4-M
# 2187                                               NaN
# 2789                                               NaN
# 267                     Treponema denticola ATCC 35405
# 24440      Zymomonas mobilis subsp. mobilis ATCC 10988
# 64650                   Bacteroides fragilis NCTC 9343
# 65011                   Bacteroides vulgatus ATCC 8482
# 65280              Porphyromonas gingivalis ATCC 33277
# 65354                  Wolinella succinogenes DSM 1740
# 65376      Fusobacterium nucleatum subsp. animalis 7_1
# 65659                                              NaN
# 65994               Chlorobium phaeovibrioides DSM 265
# 66002                        Chlorobaculum tepidum TLS
# 66006                 Chloroflexus aurantiacus J-10-fl
# 79982                       Deinococcus radiodurans R1
# 94885                 Enterococcus faecalis ATCC 19433
# 104554     Hungateiclostridium thermocellum ATCC 27405
# 119755                        Thermotoga maritima MSB8
# 136455            Caldicellulosiruptor bescii DSM 6725
# 138326            Acidobacterium capsulatum ATCC 51196
# 138848                    Geobacter sulfurreducens PCA
# 140989                    Thermus scotoductus DSM 8553
# 141249        Shewanella algae JCM 21037 = NBRC 103173
# 143932                                             NaN
# 145707                                             NaN
# 148743                         Ruegeria pomeroyi DSS-3
# 149954                                             NaN
# 153864                                             NaN
# 153917                                             NaN
# 154114                    Gemmatimonas aurantiaca T-27
# 156222            Akkermansia muciniphila ATCC BAA-835
# 157457                     Rhodopirellula baltica SH 1
# 158365                                             NaN
# 158569                      Persephonella marina EX-H1
# 160488             Proteiniclasticum ruminis DSM 24773
# 161269                                             NaN
# 162643  Thermoanaerobacter pseudethanolicus ATCC 33223
# 162840                  Dictyoglomus turgidum DSM 6724
# 163143                                             NaN
# 164950                                             NaN
# 168375                                             NaN
# 44              Methanocaldococcus jannaschii DSM 2661
# 62                            Methanosarcina mazei S-6
# 143                             Haloferax volcanii DS2
# 158                       Pyrococcus furiosus DSM 3638
# 252                    Pyrobaculum aerophilum str. IM2
# 283                                                NaN
# 429                     Sulfurisphaera tokodaii str. 7
# 452                       Ignicoccus hospitalis KIN4/I
# 546                       Aciduliprofundum boonei T469

# %%
# build a new dataframe that has a single column of lineages in it
def make_combined_lineage(row):
    x = []
    for rank in ('superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species'):
        name = getattr(row, rank)
        # turn NaN/empty into ''
        if pd.isnull(name):
            name = ''
        x.append(lca_utils.LineagePair(rank, name))
    return dict(genome_id=row.accession, combined_lineage=tuple(x))

lineages2_df = lineages_df.apply(make_combined_lineage, axis=1, result_type='expand')

lineages2_df.set_index("genome_id")
lineages2_df.reindex(index=gather_df["genome_id"])
_ = lineages2_df.reset_index()

# %%
# build a merged df that contains stuff from gather_df
merged_lin_df = gather_df.merge(lineages2_df[['genome_id','combined_lineage']], on='genome_id', how='left')

merged_lin_df[["genome_id", "name", "combined_lineage"]]
# Out:
#         genome_id                                               name  \
# 0   GCF_000196115          GCF_000196115.1 s__Rhodopirellula baltica
# 1   GCA_000018565       GCA_000018565.1 s__Herpetosiphon aurantiacus
# 2   GCF_000009705          GCF_000009705.1 s__Trichormus sp000009705
# 3   GCF_000018865        GCF_000018865.1 s__Chloroflexus aurantiacus
# 4   GCF_000012825            GCF_000012825.1 s__Phocaeicola vulgatus
# 5   GCF_000010305         GCF_000010305.1 s__Gemmatimonas aurantiaca
# 6   GCF_000011965             GCF_000011965.2 s__Ruegeria_B pomeroyi
# 7   GCF_006716065        GCF_006716065.1 s__Micromonospora arenicola
# 8   GCF_000022565       GCF_000022565.1 s__Acidobacterium capsulatum
# 9   GCF_000007985        GCF_000007985.2 s__Geobacter sulfurreducens
# 10  GCF_000025685              GCF_000025685.1 s__Haloferax volcanii
# 11  GCF_000015865  GCF_000015865.1 s__Hungateiclostridium thermoc...
# 12  GCF_001525555            GCF_001525555.1 s__Bordetella pertussis
# 13  GCF_000008185           GCF_000008185.1 s__Treponema_B denticola
# 14  GCF_000008565         GCF_000008565.1 s__Deinococcus radiodurans
# 15  GCF_900106935         GCF_900106935.1 s__Sulfitobacter pontiacus
# 16  GCF_000020225         GCF_000020225.1 s__Akkermansia muciniphila
# 17  GCF_000022325     GCF_000022325.1 s__Caldicellulosiruptor bescii
# 18  GCF_000011205         GCF_000011205.1 s__Sulfurisphaera tokodaii
# 19  GCF_000392875           GCF_000392875.1 s__Enterococcus faecalis
# 20  GCF_000196135          GCF_000196135.1 s__Wolinella succinogenes
# 21  GCF_000007225          GCF_000007225.1 s__Pyrobaculum aerophilum
# 22  GCF_000006985           GCF_000006985.1 s__Chlorobaculum tepidum
# 23  GCF_000019085  GCF_000019085.1 s__Thermoanaerobacter pseudeth...
# 24  GCF_000021565            GCF_000021565.1 s__Persephonella marina
# 25  GCF_000007305             GCF_000007305.1 s__Pyrococcus furiosus
# 26  GCF_000010505        GCF_000010505.1 s__Porphyromonas gingivalis
# 27  GCF_000021645           GCF_000021645.1 s__Dictyoglomus turgidum
# 28  GCF_000016085      GCF_000016085.1 s__Chlorobium phaeovibrioides
# 29  GCF_000008545             GCF_000008545.1 s__Thermotoga maritima
# 30  GCF_000020325  GCF_000020325.1 s__Sulfurihydrogenibium sp0000...
# 31  GCF_000175255               GCF_000175255.2 s__Zymomonas mobilis
# 32  GCF_000091665   GCF_000091665.1 s__Methanocaldococcus jannaschii
# 33  GCF_000701905       GCF_000701905.1 s__Proteiniclasticum ruminis
# 34  GCF_000025665         GCF_000025665.1 s__Aciduliprofundum boonei
# 35  GCF_002902965        GCF_002902965.1 s__Paraburkholderia hospita
# 36  GCF_000017945         GCF_000017945.1 s__Ignicoccus_A hospitalis
# 37  GCF_002945325       GCF_002945325.1 s__Methanococcus maripaludis
# 38  GCF_000213785    GCF_000213785.1 s__Hydrogenobaculum sp000213785
# 39  GCF_000158275          GCF_000158275.2 s__Fusobacterium animalis
# 40  GCA_002201895        GCA_002201895.1 s__Methanopyrus sp002201895
# 41  GCF_000970205            GCF_000970205.1 s__Methanosarcina mazei
# 42  GCF_004216565              GCF_004216565.1 s__Leptothrix mobilis
# 43  GCF_001598875                GCF_001598875.1 s__Shewanella algae
# 44  GCF_003201195           GCF_003201195.1 s__Nitrosomonas eutropha
# 45  GCF_000025985            GCF_000025985.1 s__Bacteroides fragilis
# 46  GCA_000008085           GCA_000008085.1 s__Nanoarchaeum equitans
# 47  GCF_000381045             GCF_000381045.1 s__Thermus scotoductus
# 48  GCF_000226255  GCF_000226255.1 s__Nitratidesulfovibrio sp0002...
# 49  GCF_001544555              GCF_001544555.2 s__Caballeronia udeis
# 50  GCA_002507545       GCA_002507545.1 s__Archaeoglobus sp002507545
# 51  GCF_003201595           GCF_003201595.1 s__Sphaerotilus_A hippei
#
#                                      combined_lineage
# 0   ((superkingdom, Bacteria), (phylum, Planctomyc...
# 1   ((superkingdom, Bacteria), (phylum, Chloroflex...
# 2   ((superkingdom, Bacteria), (phylum, Cyanobacte...
# 3   ((superkingdom, Bacteria), (phylum, Chloroflex...
# 4   ((superkingdom, Bacteria), (phylum, Bacteroide...
# 5   ((superkingdom, Bacteria), (phylum, Gemmatimon...
# 6   ((superkingdom, Bacteria), (phylum, Proteobact...
# 7   ((superkingdom, Bacteria), (phylum, Actinobact...
# 8   ((superkingdom, Bacteria), (phylum, Acidobacte...
# 9   ((superkingdom, Bacteria), (phylum, Proteobact...
# 10  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 11  ((superkingdom, Bacteria), (phylum, Firmicutes...
# 12                                                NaN
# 13  ((superkingdom, Bacteria), (phylum, Spirochaet...
# 14  ((superkingdom, Bacteria), (phylum, Deinococcu...
# 15  ((superkingdom, Bacteria), (phylum, Proteobact...
# 16  ((superkingdom, Bacteria), (phylum, Verrucomic...
# 17  ((superkingdom, Bacteria), (phylum, Firmicutes...
# 18  ((superkingdom, Archaea), (phylum, Crenarchaeo...
# 19  ((superkingdom, Bacteria), (phylum, Firmicutes...
# 20  ((superkingdom, Bacteria), (phylum, Proteobact...
# 21  ((superkingdom, Archaea), (phylum, Crenarchaeo...
# 22  ((superkingdom, Bacteria), (phylum, Chlorobi),...
# 23  ((superkingdom, Bacteria), (phylum, Firmicutes...
# 24  ((superkingdom, Bacteria), (phylum, Aquificae)...
# 25  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 26  ((superkingdom, Bacteria), (phylum, Bacteroide...
# 27  ((superkingdom, Bacteria), (phylum, Dictyoglom...
# 28  ((superkingdom, Bacteria), (phylum, Chlorobi),...
# 29  ((superkingdom, Bacteria), (phylum, Thermotoga...
# 30  ((superkingdom, Bacteria), (phylum, Aquificae)...
# 31  ((superkingdom, Bacteria), (phylum, Proteobact...
# 32  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 33  ((superkingdom, Bacteria), (phylum, Firmicutes...
# 34  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 35  ((superkingdom, Bacteria), (phylum, Proteobact...
# 36  ((superkingdom, Archaea), (phylum, Crenarchaeo...
# 37  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 38  ((superkingdom, Bacteria), (phylum, Aquificae)...
# 39  ((superkingdom, Bacteria), (phylum, Fusobacter...
# 40  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 41  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 42  ((superkingdom, Bacteria), (phylum, Proteobact...
# 43  ((superkingdom, Bacteria), (phylum, Proteobact...
# 44  ((superkingdom, Bacteria), (phylum, Proteobact...
# 45  ((superkingdom, Bacteria), (phylum, Bacteroide...
# 46  ((superkingdom, Archaea), (phylum, Nanoarchaeo...
# 47  ((superkingdom, Bacteria), (phylum, Deinococcu...
# 48  ((superkingdom, Bacteria), (phylum, Proteobact...
# 49  ((superkingdom, Bacteria), (phylum, Proteobact...
# 50  ((superkingdom, Archaea), (phylum, Euryarchaeo...
# 51  ((superkingdom, Bacteria), (phylum, Proteobact...

# %%
pylab.figure(num=None, figsize=(8, 6))
pylab.plot(gather_df.index, gather_df["f_unique_to_query"]*100, '.')

pylab.title('fraction of hashes unique to query')
pylab.xlabel('gather rank order')
pylab.ylabel('f_unique_to_query, as %')
# Out:
# Text(0, 0.5, 'f_unique_to_query, as %')

# %% [markdown]
# ## Taxonomy stuff

# %%
# create function that aggregates various pieces of information by rank & builds a new df
def aggregate_by_rank(df, rank):
    # first, build all the counts
    unique_intersect_by_rank = defaultdict(int)
    best_hashes_by_rank = {}

    def sum_unique(row):
        lin = row.combined_lineage
        if pd.isnull(lin):
            lin = []
        unique_hashes = row.unique_intersect_bp

        for rank in ('superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species'):
            poplin = lca_utils.pop_to_rank(lin, rank)
            unique_intersect_by_rank[poplin] += unique_hashes
            
            best_hashes = best_hashes_by_rank.get(poplin, 0)
            if best_hashes < unique_hashes:
                best_hashes_by_rank[poplin] = unique_hashes

    df.apply(sum_unique, axis=1)

    # now do the sorting etc.
    rank_counts = []
    for lin, bp in sorted(unique_intersect_by_rank.items(), key=lambda x: -x[1]):
        if lin and lin[-1].rank == rank:
            
            if rank == 'species':
                name = lin[-1].name
                name = f'{name} ({lin[0].name})'
            else:
                name = lca_utils.display_lineage(lin)

            rank_counts.append(dict(name=name, hashes=bp,
                                    best_hashes=best_hashes_by_rank[lin],
                                    lineage=lin))

    return pd.DataFrame(rank_counts)

test_df = aggregate_by_rank(merged_lin_df, 'species')

# %%
for rank in lca_utils.taxlist(include_strain=False):
    print(f'computing and saving for {rank}')
    rank_counts_df = aggregate_by_rank(merged_lin_df, rank)
    rank_counts_df.to_csv(f'podar-protein-{rank}.csv')
# Out:
# computing and saving for superkingdom
# computing and saving for phylum
# computing and saving for class
# computing and saving for order
# computing and saving for family
# computing and saving for genus
# computing and saving for species

# %%
pylab.figure(num=None, figsize=(10, 10))

plot_df = gather_df[:60]
labels_df = names_df[:60]

pylab.plot(plot_df.intersect_bp / 1e6, plot_df.iloc[::-1].index, 'gx', label='hashes classified to this species')
pylab.plot(plot_df.unique_intersect_bp / 1e6, plot_df.iloc[::-1].index, 'ro', label='hashes classified for this genome')

positions = list(plot_df.index)
labels = list(reversed(labels_df.ncbi_tax_name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('number (millions)')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes, genome/strain-level identity report')
pylab.tight_layout()

pylab.savefig(f'/tmp/gathergram-{sample_id}.hashes.png')

# %%
rank = 'species'

pylab.figure(num=None, figsize=(10, 10))

rank_counts_df = aggregate_by_rank(merged_lin_df, rank)
rank_counts_df.to_csv(f'podar-protein-{rank}.csv')

plot_df = rank_counts_df[:40]
pylab.plot(plot_df.hashes, plot_df.iloc[::-1].index, 'bo', label='hashes')
pylab.plot(plot_df.best_hashes, plot_df.iloc[::-1].index, 'gx', label='best single genome (hashes)')

positions = list(plot_df.index)
labels = list(reversed(plot_df.name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('bp')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes, by {rank}')
pylab.tight_layout()

figname = f'/tmp/gathergram-{rank}-{sample_id}.png'
print(f'saving to {figname}')
pylab.savefig(figname)
# Out:
# saving to /tmp/gathergram-species-SRR606249.png

# %%
rank = 'genus'

pylab.figure(num=None, figsize=(10, 10))

rank_counts_df = aggregate_by_rank(merged_lin_df, rank)
rank_counts_df.to_csv(f'podar-protein-{rank}.csv')

plot_df = rank_counts_df[:40]
pylab.plot(plot_df.hashes, plot_df.iloc[::-1].index, 'bo', label='hashes')
pylab.plot(plot_df.best_hashes, plot_df.iloc[::-1].index, 'gx', label='best single genome (hashes)')

positions = list(plot_df.index)
labels = list(reversed(plot_df.name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('bp')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes, by {rank}')
pylab.tight_layout()

figname = f'/tmp/gathergram-{rank}-{sample_id}.png'
print(f'saving to {figname}')
pylab.savefig(figname)
# Out:
# saving to /tmp/gathergram-genus-SRR606249.png

# %%
rank = 'phylum'

pylab.figure(num=None, figsize=(10, 10))

rank_counts_df = aggregate_by_rank(merged_lin_df, rank)
rank_counts_df.to_csv(f'podar-protein-{rank}.csv')

plot_df = rank_counts_df[:40]
pylab.plot(plot_df.hashes, plot_df.iloc[::-1].index, 'bo', label='hashes')
pylab.plot(plot_df.best_hashes, plot_df.iloc[::-1].index, 'gx', label='best single genome (hashes)')

positions = list(plot_df.index)
labels = list(reversed(plot_df.name))
pylab.yticks(positions, labels, fontsize='small')

pylab.xlabel('bp')
pylab.legend(loc='lower right')
pylab.title(f'{sample_id}: gather hashes, by {rank}')
pylab.tight_layout()

figname = f'/tmp/gathergram-{rank}-{sample_id}.png'
print(f'saving to {figname}')
pylab.savefig(figname)
# Out:
# saving to /tmp/gathergram-phylum-SRR606249.png
